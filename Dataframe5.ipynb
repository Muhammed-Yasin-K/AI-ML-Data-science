# %% [markdown]
# DataFrame Program-5

# %%
import pandas as pd

data = {
    'Age': [23, 45, 31, 35],
    'Name': ['Ania', 'Arushi', 'Ram', 'Shyam'],
    'Salary': [70000, 120000, 90000, 110000],
    'Manager': [True, False, True, False]
}

df = pd.DataFrame(data)
df

df[['Name','Manager']].describe()
# Out:
#         Name Manager
# count      4       4
# unique     4       2
# top     Ania    True
# freq       1       2

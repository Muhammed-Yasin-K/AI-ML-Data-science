# %% [markdown]
# DataFrame Program-4

# %%
import pandas as pd

data = {'score':[45,67,89,34,78,56,92,73]}

df = pd.DataFrame(data)
df

df.describe(percentiles=[0.1,0.5,0.9])
# Out:
#            score
# count   8.000000
# mean   66.750000
# std    20.561754
# min    34.000000
# 10%    41.700000
# 50%    70.000000
# 90%    89.900000
# max    92.000000
